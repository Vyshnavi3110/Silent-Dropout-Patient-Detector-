# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')


from sklearn.svm import SVC
from sklearn.utils.class_weight import compute_class_weight

sns.set(style="whitegrid")
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV, StratifiedKFold

from sklearn.metrics import accuracy_score, classification_report

from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier

# %%
data = pd.read_csv('/content/silent_dropout_patients.csv')
data.head()
# Out:
#      Patient_Name Last_Follow_Up_Date  Expected_Gap_Between_Visits_days  \
# 0  David Williams          2024-12-12                                15
# 1     Laura Brown          2023-11-30                                55
# 2  David Martinez          2022-06-27                                36
# 3     Alex Miller          2024-09-19                                43
# 4     Laura Brown          2023-07-20                                28
#
#    Medicine_Refill_Delay_days  Days_Since_Last_Contact  Missed_Lab_Tests  \
# 0                          16                       71                 0
# 1                          33                       62                 3
# 2                          23                       86                 4
# 3                           9                       49                 3
# 4                          29                       88                 5
#
#    Days_Late_Follow_Up  Silent_Dropout_Score Risk_Level
# ...

# %%
# Check missing values count
missing_values = data.isnull().sum()

missing_values[missing_values > 0]
# Out:
# Series([], dtype: int64)

# %%
numeric_cols = data.select_dtypes(include=['int64', 'float64']).columns
numeric_cols
outlier_summary = {}

for col in numeric_cols:
    Q1 = data[col].quantile(0.25)
    Q3 = data[col].quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR

    outliers = data[(data[col] < lower) | (data[col] > upper)]
    outlier_summary[col] = outliers.shape[0]

outlier_summary
# Out:
# {'Expected_Gap_Between_Visits_days': 0,
#  'Medicine_Refill_Delay_days': 0,
#  'Days_Since_Last_Contact': 0,
#  'Missed_Lab_Tests': 0,
#  'Days_Late_Follow_Up': 0,
#  'Silent_Dropout_Score': 47}

# %%
data['Silent_Dropout_Score'] = np.clip(
    data['Silent_Dropout_Score'],
    data['Silent_Dropout_Score'].quantile(0.05),
    data['Silent_Dropout_Score'].quantile(0.95)
)

# %%
outlier_count_after = {}

for col in numeric_cols:
    Q1 = data[col].quantile(0.25)
    Q3 = data[col].quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR

    count = ((data[col] < lower) | (data[col] > upper)).sum()
    outlier_count_after[col] = count

outlier_count_after
# Out:
# {'Expected_Gap_Between_Visits_days': np.int64(0),
#  'Medicine_Refill_Delay_days': np.int64(0),
#  'Days_Since_Last_Contact': np.int64(0),
#  'Missed_Lab_Tests': np.int64(0),
#  'Days_Late_Follow_Up': np.int64(0),
#  'Silent_Dropout_Score': np.int64(0)}

# %%
le = LabelEncoder()
data['Neglect_Risk_Level_num'] = le.fit_transform(data['Risk_Level'])

data[['Risk_Level', 'Neglect_Risk_Level_num']].head()
# Out:
#   Risk_Level  Neglect_Risk_Level_num
# 0       HIGH                       0
# 1       HIGH                       0
# 2       HIGH                       0
# 3     MEDIUM                       2
# 4       HIGH                       0

# %%
X = data.drop(columns=['Risk_Level', 'Neglect_Risk_Level_num'])
y = data['Neglect_Risk_Level_num']

# %%
X = pd.get_dummies(X)

# %%
X[numeric_cols] = X[numeric_cols] + np.random.randint(0, 2, size=X[numeric_cols].shape)

# %%
scaler = StandardScaler()
X[numeric_cols] = scaler.fit_transform(X[numeric_cols])

# %%
plt.figure(figsize=(8,5))
sns.histplot(data['Expected_Gap_Between_Visits_days'], bins=15, kde=True)
plt.title("Expected Gap Between Visits Distribution")
plt.xlabel("Gap Days")
plt.ylabel("Patients")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.histplot(data['Days_Since_Last_Contact'], bins=10, kde=True)
plt.title("Days Since Last Contact Distribution")
plt.xlabel("Days")
plt.ylabel("Patients")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.histplot(data['Medicine_Refill_Delay_days'], bins=15, kde=True)
plt.title("Medicine Refill Delay Distribution")
plt.xlabel("Delay Days")
plt.ylabel("Patients")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='Missed_Lab_Tests', data=data)
plt.title("Missed Lab Tests Count")
plt.xlabel("Number of Missed Tests")
plt.ylabel("Patients")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.histplot(data['Days_Late_Follow_Up'], bins=30, kde=True)
plt.title("Days Late Follow-Up Distribution")
plt.xlabel("Late Days")
plt.ylabel("Patients")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.histplot(data['Silent_Dropout_Score'], bins=30, kde=True)
plt.title("Silent Dropout Score Distribution")
plt.xlabel("Score")
plt.ylabel("Patients")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.violinplot(
    x='Dropout_Risk_Level',
    y='Days_Since_Last_Contact',
    data=data
)
plt.title("Violin Plot: Contact Gap by Risk Level")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.boxplot(
    x='Dropout_Risk_Level',
    y='Days_Since_Last_Contact',
    data=data,
    showfliers=False
)
plt.title("Days Since Last Contact vs Dropout Risk Level")
plt.xlabel("Dropout Risk Level")
plt.ylabel("Days Since Last Contact")
plt.show()

# %%
mean_days = data.groupby('Dropout_Risk_Level')['Days_Since_Last_Contact'].mean()

mean_days.plot(kind='bar', figsize=(6,4))
plt.title("Average Days Since Last Contact by Risk Level")
plt.ylabel("Average Days")
plt.show()

# %%
Q1 = data['Silent_Dropout_Score'].quantile(0.25)
Q3 = data['Silent_Dropout_Score'].quantile(0.75)
IQR = Q3 - Q1

lower = Q1 - 1.5*IQR
upper = Q3 + 1.5*IQR

(data['Silent_Dropout_Score'] < lower).sum(), \
(data['Silent_Dropout_Score'] > upper).sum()
# Out:
# (np.int64(0), np.int64(0))

# %%
# Select only numeric columns
numeric_cols = data.select_dtypes(include=['int64', 'float64'])

plt.figure(figsize=(10,6))
sns.heatmap(
    numeric_cols.corr(),
    annot=True,
    cmap='coolwarm'
)
plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, stratify=y, random_state=42
)

# %%
models = {
    'RandomForest': RandomForestClassifier(
        n_estimators=150, max_depth=10, min_samples_leaf=2, random_state=42
    ),
    'DecisionTree': DecisionTreeClassifier(
        max_depth=9, min_samples_leaf=4, random_state=42
    ),
    'LogisticRegression': LogisticRegression(
        max_iter=1000, C=1.0, penalty='l1', solver='liblinear'
    ),
    'SVM': SVC(C=1.0, kernel='rbf', gamma='scale'),
    'KNN': KNeighborsClassifier(n_neighbors=5)
}

# %%
results = []

for name, model in models.items():
    cv_score = cross_val_score(model, X_train, y_train, cv=5).mean()
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    test_acc = accuracy_score(y_test, y_pred)

    results.append([name, cv_score, test_acc])

    print(f"--- {name} ---")
    print("CV Accuracy:", round(cv_score, 4))
    print("Test Accuracy:", round(test_acc, 4))
    print(classification_report(y_test, y_pred))
    print("-"*55)
# Out:
# --- RandomForest ---
# CV Accuracy: 0.6966
# Test Accuracy: 0.7027
#               precision    recall  f1-score   support
#
#            0       0.71      1.00      0.83      1031
#            1       0.00      0.00      0.00       153
#            2       0.59      0.07      0.13       316
#
#     accuracy                           0.70      1500
#    macro avg       0.43      0.36      0.32      1500
# weighted avg       0.61      0.70      0.60      1500
#
# -------------------------------------------------------
# --- DecisionTree ---
# CV Accuracy: 0.9517
# Test Accuracy: 0.96
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      1031
#            1       0.93      0.93      0.93       153
#            2       0.93      0.88      0.90       316
#
#     accuracy                           0.96      1500
#    macro avg       0.94      0.93      0.94      1500
# weighted avg       0.96      0.96      0.96      1500
#
# ...

# %%
results_df = pd.DataFrame(results, columns=['Model', 'CV Accuracy', 'Test Accuracy'])
results_df
# Out:
#                 Model  CV Accuracy  Test Accuracy
# 0        RandomForest     0.696571       0.702667
# 1        DecisionTree     0.951714       0.960000
# 2  LogisticRegression     0.963429       0.960000
# 3                 SVM     0.961429       0.964000
# 4                 KNN     0.920000       0.916667

# %%
results_df.sort_values(by='Test Accuracy', ascending=False)
# Out:
#                 Model  CV Accuracy  Test Accuracy
# 3                 SVM     0.961429       0.964000
# 2  LogisticRegression     0.963429       0.960000
# 1        DecisionTree     0.951714       0.960000
# 4                 KNN     0.920000       0.916667
# 0        RandomForest     0.696571       0.702667

# %%
from sklearn.utils.class_weight import compute_class_weight
import numpy as np

# Compute class weights
class_weights = compute_class_weight('balanced', classes=np.unique(y_train), y=y_train)
class_weights_dict = {i: w for i, w in enumerate(class_weights)}

# Example: update RandomForest
models['RandomForest'] = RandomForestClassifier(
    n_estimators=150, max_depth=10, min_samples_leaf=2,
    class_weight=class_weights_dict, random_state=42
)

# Do the same for DecisionTree, LogisticRegression, SVM if you want

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE(random_state=42)
X_train_res, y_train_res = smote.fit_resample(X_train, y_train)

# %%
from sklearn.preprocessing import StandardScaler

numeric_cols = X.select_dtypes(include=['int64','float64']).columns
scaler = StandardScaler()
X_train[numeric_cols] = scaler.fit_transform(X_train[numeric_cols])
X_test[numeric_cols] = scaler.transform(X_test[numeric_cols])

# %%
X_train_res[numeric_cols] = scaler.fit_transform(X_train_res[numeric_cols])

# %%
from sklearn.model_selection import cross_val_score, StratifiedKFold
from sklearn.metrics import accuracy_score, classification_report

results = []
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

for name, model in models.items():
    if 'X_train_res' in locals():
        X_tr, y_tr = X_train_res, y_train_res
    else:
        X_tr, y_tr = X_train, y_train

    cv_score = cross_val_score(model, X_tr, y_tr, cv=cv, scoring='f1_macro').mean()
    model.fit(X_tr, y_tr)

    y_pred = model.predict(X_test)
    test_acc = accuracy_score(y_test, y_pred)

    results.append([name, cv_score, test_acc])

    print(f"--- {name} ---")
    print("CV Macro F1:", round(cv_score, 4))
    print("Test Accuracy:", round(test_acc, 4))
    print(classification_report(y_test, y_pred))
    print("-"*50)

import pandas as pd
results_df = pd.DataFrame(results, columns=['Model', 'CV Macro F1', 'Test Accuracy'])
results_df.sort_values(by='Test Accuracy', ascending=False)
# Out:
# --- RandomForest ---
# CV Macro F1: 0.7159
# Test Accuracy: 0.2533
#               precision    recall  f1-score   support
#
#            0       1.00      0.19      0.32      1031
#            1       0.19      1.00      0.32       153
#            2       0.06      0.10      0.08       316
#
#     accuracy                           0.25      1500
#    macro avg       0.42      0.43      0.24      1500
# weighted avg       0.72      0.25      0.27      1500
#
# --------------------------------------------------
# --- DecisionTree ---
# CV Macro F1: 0.9721
# Test Accuracy: 0.5907
#               precision    recall  f1-score   support
#
#            0       1.00      0.65      0.79      1031
#            1       0.38      1.00      0.55       153
#            2       0.15      0.19      0.17       316
#
#     accuracy                           0.59      1500
#    macro avg       0.51      0.61      0.50      1500
# weighted avg       0.76      0.59      0.63      1500
#
# ...

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, stratify=y, random_state=42
)

# %%
svc_model = SVC(C=1.0, kernel='rbf', gamma='scale', class_weight=class_weights_dict)

# %%
from sklearn.model_selection import StratifiedKFold, GridSearchCV
from sklearn.svm import SVC
from sklearn.metrics import classification_report, accuracy_score

# Smaller parameter grid for faster tuning
param_grid = {
    'C': [0.1, 1],          # fewer values
    'gamma': ['scale', 0.1], # fewer options
    'kernel': ['rbf']        # focus on one kernel first
}

# Stratified CV
cv = StratifiedKFold(n_splits=3, shuffle=True, random_state=42)  # reduce folds to speed up

# Define SVC with class weights
svc_model = SVC(class_weight='balanced')  # or use your class_weights_dict

# Grid search
grid = GridSearchCV(svc_model, param_grid, cv=cv, scoring='f1_macro')
grid.fit(X_train, y_train)

# Results
print("Best Params:", grid.best_params_)
print("Best CV Macro F1:", grid.best_score_)

# Test evaluation
y_pred = grid.predict(X_test)
print("Test Accuracy:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Best Params: {'C': 1, 'gamma': 'scale', 'kernel': 'rbf'}
# Best CV Macro F1: 0.9312667897541992
# Test Accuracy: 0.956
#               precision    recall  f1-score   support
#
#            0       0.99      0.97      0.98      1031
#            1       0.90      0.95      0.92       153
#            2       0.87      0.93      0.90       316
#
#     accuracy                           0.96      1500
#    macro avg       0.92      0.95      0.93      1500
# weighted avg       0.96      0.96      0.96      1500

# %%
import pickle

# Final trained SVM model
final_svm_model = grid.best_estimator_

# Save model
with open('svm_model.pkl', 'wb') as f:
    pickle.dump(final_svm_model, f)

# Save scaler
with open('scaler.pkl', 'wb') as f:
    pickle.dump(scaler, f)

# Save label encoder
with open('label_encoder.pkl', 'wb') as f:
    pickle.dump(le, f)

# Save feature columns (important for prediction)
with open('feature_columns.pkl', 'wb') as f:
    pickle.dump(X.columns.tolist(), f)

print("✅ Pickle files saved successfully")
# Out:
# ✅ Pickle files saved successfully

# %%
import pickle
import pandas as pd

# Load model & preprocessors
with open('svm_model.pkl', 'rb') as f:
    svm_model = pickle.load(f)

with open('scaler.pkl', 'rb') as f:
    scaler = pickle.load(f)

with open('label_encoder.pkl', 'rb') as f:
    le = pickle.load(f)

with open('feature_columns.pkl', 'rb') as f:
    feature_columns = pickle.load(f)

# %%
# %%writefile app.py
import streamlit as st
import pandas as pd
import pickle

# ---------------- Page Config ----------------
st.set_page_config(
    page_title="Silent Dropout Prediction",
    page_icon="⚠️",
    layout="centered"
)

st.title("⚠️ Silent Dropout Risk Prediction")
st.write("Predict patient silent dropout risk using SVM")

# ---------------- Load Pickle Files ----------------
@st.cache_resource
def load_models():
    with open("svm_model.pkl", "rb") as f:
        model = pickle.load(f)

    with open("scaler.pkl", "rb") as f:
        scaler = pickle.load(f)

    with open("label_encoder.pkl", "rb") as f:
        label_encoder = pickle.load(f)

    with open("feature_columns.pkl", "rb") as f:
        feature_columns = pickle.load(f)

    return model, scaler, label_encoder, feature_columns


model, scaler, le, feature_columns = load_models()

# ---------------- User Inputs ----------------
st.subheader("🧾 Patient Details")

days_last_contact = st.number_input("Days Since Last Contact", 0, 365, 10)
expected_gap = st.number_input("Expected Gap Between Visits (days)", 0, 365, 7)
refill_delay = st.number_input("Medicine Refill Delay (days)", 0, 180, 2)
missed_tests = st.number_input("Missed Lab Tests", 0, 10, 0)
late_followup = st.number_input("Days Late for Follow-Up", 0, 365, 5)

# IMPORTANT: match training range
silent_score = st.slider("Silent Dropout Score", 0.0, 100.0, 30.0)

# ---------------- Prediction ----------------
if st.button("🔮 Predict Risk Level"):

    # Create input dataframe
    input_df = pd.DataFrame([{
        "Days_Since_Last_Contact": days_last_contact,
        "Expected_Gap_Between_Visits_days": expected_gap,
        "Medicine_Refill_Delay_days": refill_delay,
        "Missed_Lab_Tests": missed_tests,
        "Days_Late_Follow_Up": late_followup,
        "Silent_Dropout_Score": silent_score
    }])

    # Align with training columns
    input_df = input_df.reindex(columns=feature_columns, fill_value=0)

    # 🔑 SCALE ENTIRE INPUT (NOT PARTIAL)
    input_scaled = scaler.transform(input_df)

    # Predict
    pred = model.predict(input_scaled)
    risk = le.inverse_transform(pred)[0]

    # ---------------- Output ----------------
    st.subheader("📊 Prediction Result")

    if risk.lower() == "high":
        st.error("🚨 HIGH Risk of Silent Dropout")
    elif risk.lower() == "medium":
        st.warning("⚠️ MEDIUM Risk of Silent Dropout")
    else:
        st.success("✅ LOW Risk of Silent Dropout")

    st.write("**Predicted Risk Level:**", risk)
# Out:
# Writing app.py

# %%
requirements = [
    "streamlit",
    "pandas",
    "numpy",
    "scikit-learn",
    "matplotlib",
    "seaborn",
    "imbalanced-learn"
]

with open("requirements.txt", "w") as f:
    for pkg in requirements:
        f.write(pkg + "\n")

print("requirements.txt created successfully")
# Out:
# requirements.txt created successfully
